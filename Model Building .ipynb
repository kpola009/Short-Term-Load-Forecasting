# %%
import pandas as pd
import numpy as np

# %%
final_df = pd.read_csv("final_df_1987_1989.csv")
final_df
# Out:
#        Unnamed: 0                 date  Load    AvgL(k-1)  max_sub_avg_load  \
# 0               0  1987-01-01 00:00:00  4521          NaN               NaN
# 1               1  1987-01-01 01:00:00  4181          NaN               NaN
# 2               2  1987-01-01 02:00:00  3870          NaN               NaN
# 3               3  1987-01-01 03:00:00  3730          NaN               NaN
# 4               4  1987-01-01 04:00:00  3744          NaN               NaN
# ...           ...                  ...   ...          ...               ...
# 26299       26299  1989-12-31 19:00:00  7842  6479.833333      2.217617e+06
# 26300       26300  1989-12-31 20:00:00  7186  6479.833333      2.217617e+06
# 26301       26301  1989-12-31 21:00:00  6645  6479.833333      2.217617e+06
# 26302       26302  1989-12-31 22:00:00  6195  6479.833333      2.217617e+06
# 26303       26303  1989-12-31 23:00:00  5692  6479.833333      2.217617e+06
#
# ...

# %%
final_df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
final_df
# Out:
#                       date  Load    AvgL(k-1)  max_sub_avg_load  \
# 0      1987-01-01 00:00:00  4521          NaN               NaN
# 1      1987-01-01 01:00:00  4181          NaN               NaN
# 2      1987-01-01 02:00:00  3870          NaN               NaN
# 3      1987-01-01 03:00:00  3730          NaN               NaN
# 4      1987-01-01 04:00:00  3744          NaN               NaN
# ...                    ...   ...          ...               ...
# 26299  1989-12-31 19:00:00  7842  6479.833333      2.217617e+06
# 26300  1989-12-31 20:00:00  7186  6479.833333      2.217617e+06
# 26301  1989-12-31 21:00:00  6645  6479.833333      2.217617e+06
# 26302  1989-12-31 22:00:00  6195  6479.833333      2.217617e+06
# 26303  1989-12-31 23:00:00  5692  6479.833333      2.217617e+06
#
#        avg_sub_min_load  L(k-1,8)  daytype  L(k-1,24)  maxL(k-1)  minL(k-1)  \
# 0                   NaN       NaN    0.375        NaN        NaN        NaN
# ...

# %%
final_df_1990 = pd.read_csv("final_df_1990.csv")

# %%
final_df_1990
# Out:
#       Unnamed: 0                 date  Load    AvgL(k-1)  max_sub_avg_load  \
# 0              0  1990-01-01 00:00:00  5407          NaN               NaN
# 1              1  1990-01-01 01:00:00  4980          NaN               NaN
# 2              2  1990-01-01 02:00:00  4658          NaN               NaN
# 3              3  1990-01-01 03:00:00  4491          NaN               NaN
# 4              4  1990-01-01 04:00:00  4469          NaN               NaN
# ...          ...                  ...   ...          ...               ...
# 8755        8755  1990-12-31 19:00:00  8998  7179.916667      3.798926e+06
# 8756        8756  1990-12-31 20:00:00  8195  7179.916667      3.798926e+06
# 8757        8757  1990-12-31 21:00:00  7530  7179.916667      3.798926e+06
# 8758        8758  1990-12-31 22:00:00  6951  7179.916667      3.798926e+06
# 8759        8759  1990-12-31 23:00:00  6357  7179.916667      3.798926e+06
#
# ...

# %%
final_df_1990.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
final_df_ANN1 = final_df[['daytype','AvgL(k-1)','sqr[maxL(k-1)-AveL(k-1)]', 'sqr[aveL(k-1)-minL(k-1)]', 'L(k-1,8)','L(l-1,h)','hourtype','Load']]
final_df_ANN2 = final_df[['daytype','L(l-1,h)','L(k-1,24)','Max L(k-1)','Min L(k-1)','hourtype','Load']]
final_df_ANN3 = final_df[['daytype', 'L(k-7,h)','hourtype','Load']]

# %%
final_df_1990_ANN1 = final_df_1990[['daytype','AvgL(k-1)','sqr[maxL(k-1)-AveL(k-1)]', 'sqr[aveL(k-1)-minL(k-1)]', 'L(k-1,8)','L(l-1,h)','hourtype','Load']]
final_df_1990_ANN2 = final_df_1990[['daytype','L(l-1,h)','L(k-1,24)','Max L(k-1)','Min L(k-1)','hourtype','Load']]
final_df_1990_ANN3 = final_df_1990[['daytype', 'L(k-7,h)','hourtype','Load']]

# %%
import matplotlib.pyplot as plt
def plot_ytrue_yhat(y_true, y_hat):
    plt.plot(y_true, label='True Load')
    plt.plot(y_hat, label='Predicted Load')
    plt.legend()

# %% [markdown]
# ### January Forecast

# %%
jan_feb_1987 = final_df_ANN1[:1416]

# %%
jan_feb_1987 = jan_feb_1987.dropna()

# %%
jan_feb_1987
# Out:
#       daytype    AvgL(k-1)  sqr[maxL(k-1)-AveL(k-1)]  \
# 24      0.500  5248.291667               1746912.918
# 25      0.500  5248.291667               1746912.918
# 26      0.500  5248.291667               1746912.918
# 27      0.500  5248.291667               1746912.918
# 28      0.500  5248.291667               1746912.918
# ...       ...          ...                       ...
# 1411    0.625  6218.041667               2464769.168
# 1412    0.625  6218.041667               2464769.168
# 1413    0.625  6218.041667               2464769.168
# 1414    0.625  6218.041667               2464769.168
# 1415    0.625  6218.041667               2464769.168
#
#       sqr[aveL(k-1)-minL(k-1)]  L(k-1,8)  L(l-1,h)  hourtype  Load
# 24                 2305209.585    4428.0    4521.0  0.000000  4280
# 25                 2305209.585    4428.0    4181.0  0.043478  4135
# 26                 2305209.585    4428.0    3870.0  0.086957  4086
# ...

# %%
nov_dec_1987 = final_df_ANN1[7296:8760]
nov_dec_1987
# Out:
#       daytype    AvgL(k-1)  sqr[maxL(k-1)-AveL(k-1)]  \
# 7296    0.750  6017.458333               2469743.210
# 7297    0.750  6017.458333               2469743.210
# 7298    0.750  6017.458333               2469743.210
# 7299    0.750  6017.458333               2469743.210
# 7300    0.750  6017.458333               2469743.210
# ...       ...          ...                       ...
# 8755    0.375  6876.916667               3179386.174
# 8756    0.375  6876.916667               3179386.174
# 8757    0.375  6876.916667               3179386.174
# 8758    0.375  6876.916667               3179386.174
# 8759    0.375  6876.916667               3179386.174
#
#       sqr[aveL(k-1)-minL(k-1)]  L(k-1,8)  L(l-1,h)  hourtype  Load
# 7296               3152252.293    5797.0    4673.0  0.000000  4947
# 7297               3152252.293    5797.0    4441.0  0.043478  4684
# 7298               3152252.293    5797.0    4294.0  0.086957  4590
# ...

# %%
jan_feb_1988 = final_df_ANN1[8760:10176]
jan_feb_1988
# Out:
#        daytype    AvgL(k-1)  sqr[maxL(k-1)-AveL(k-1)]  \
# 8760      0.50  5969.125000               1970865.016
# 8761      0.50  5969.125000               1970865.016
# 8762      0.50  5969.125000               1970865.016
# 8763      0.50  5969.125000               1970865.016
# 8764      0.50  5969.125000               1970865.016
# ...        ...          ...                       ...
# 10171     0.75  6734.958333               5299395.835
# 10172     0.75  6734.958333               5299395.835
# 10173     0.75  6734.958333               5299395.835
# 10174     0.75  6734.958333               5299395.835
# 10175     0.75  6734.958333               5299395.835
#
#        sqr[aveL(k-1)-minL(k-1)]  L(k-1,8)  L(l-1,h)  hourtype  Load
# 8760                2716316.016    6776.0    4654.0  0.000000  4721
# 8761                2716316.016    6776.0    4396.0  0.043478  4396
# 8762                2716316.016    6776.0    4321.0  0.086957  4140
# ...

# %%
nov_dec_1988 = final_df_ANN1[16056:17520]
nov_dec_1988
# Out:
#        daytype    AvgL(k-1)  sqr[maxL(k-1)-AveL(k-1)]  \
# 16056      0.0  6540.791667               2644553.543
# 16057      0.0  6540.791667               2644553.543
# 16058      0.0  6540.791667               2644553.543
# 16059      0.0  6540.791667               2644553.543
# 16060      0.0  6540.791667               2644553.543
# ...        ...          ...                       ...
# 17515      0.5  6803.791667               4117686.460
# 17516      0.5  6803.791667               4117686.460
# 17517      0.5  6803.791667               4117686.460
# 17518      0.5  6803.791667               4117686.460
# 17519      0.5  6803.791667               4117686.460
#
#        sqr[aveL(k-1)-minL(k-1)]  L(k-1,8)  L(l-1,h)  hourtype  Load
# 16056               3582660.293    6039.0    5519.0  0.000000  4961
# 16057               3582660.293    6039.0    4920.0  0.043478  4739
# 16058               3582660.293    6039.0    4758.0  0.086957  4652
# ...

# %%
jan_feb_1989 = final_df_ANN1[17520:18936]

# %%
jan_feb_1989 = jan_feb_1989.dropna()

# %%
nov_dec_1989 = final_df_ANN1[24816:26280]

# %%
jan_1990_train_frames = [jan_feb_1987,nov_dec_1987, jan_feb_1988, nov_dec_1988,jan_feb_1989, nov_dec_1989]
jan_1990_train = pd.concat(jan_1990_train_frames)

# %%
jan_1990_test = final_df_1990_ANN1[:744]
jan_1990_test = jan_1990_test.dropna()
jan_1990_test
# Out:
#      daytype    AvgL(k-1)  sqr[maxL(k-1)-AveL(k-1)]  sqr[aveL(k-1)-minL(k-1)]  \
# 24     0.500  6390.166667               3492538.028               3690881.361
# 25     0.500  6390.166667               3492538.028               3690881.361
# 26     0.500  6390.166667               3492538.028               3690881.361
# 27     0.500  6390.166667               3492538.028               3690881.361
# 28     0.500  6390.166667               3492538.028               3690881.361
# ..       ...          ...                       ...                       ...
# 739    0.625  7576.916667               5410663.674               8002769.507
# 740    0.625  7576.916667               5410663.674               8002769.507
# 741    0.625  7576.916667               5410663.674               8002769.507
# 742    0.625  7576.916667               5410663.674               8002769.507
# 743    0.625  7576.916667               5410663.674               8002769.507
#
# ...

# %%
daytype_train = jan_1990_train['daytype']
daytype_test = jan_1990_test['daytype']

hourtype_train = jan_1990_train['hourtype']
hourtype_test = jan_1990_test['hourtype']

# %%
jan_1990_train.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
jan_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
jan_1990_train_X = jan_1990_train.iloc[:, :5]
jan_1990_train_y = jan_1990_train['Load']

jan_1990_test_X = jan_1990_test.iloc[:, :5]
jan_1990_test_y = jan_1990_test['Load']

# %%
jan_1990_train_y = jan_1990_train_y.values
jan_1990_test_y = jan_1990_test_y.values

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

jan_1990_train_X_norm = scaler.fit_transform(jan_1990_train_X)
jan_1990_test_X_norm = scaler.fit_transform(jan_1990_test_X)

# %%
daytype_train = daytype_train.values

# %%
daytype_train =  daytype_train.reshape(-1,1)

# %%
daytype_train.shape
# Out:
# (8616, 1)

# %%
daytype_test = daytype_test.values
daytype_test =  daytype_test.reshape(-1,1)

# %%
hourtype_train = hourtype_train.values
hourtype_train = hourtype_train.reshape(-1,1)

# %%
hourtype_test = hourtype_test.values
hourtype_test = hourtype_test.reshape(-1,1)

# %%
jan_1989_train_X_norm = np.hstack((jan_1990_train_X_norm, daytype_train, hourtype_train))

# %%
np.isnan(jan_1989_train_X_norm).sum()
# Out:
# 0

# %%
jan_1989_test_X_norm = np.hstack((jan_1990_test_X_norm, daytype_test, hourtype_test))

# %%
np.isnan(jan_1989_test_X_norm).sum()
# Out:
# 0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.1

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Dense(20, activation = tf.keras.activations.relu),
  tf.keras.layers.Dropout(0.1),
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.002),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model.fit(jan_1990_train_X_norm, jan_1990_train_y, epochs=200)
# Out:
# Epoch 1/200
# C:\Users\ketul\anaconda3\envs\TensorflowGPU\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 270/270 [==============================] - 2s 3ms/step - loss: 6695.5415 - mae: 6695.5415
# Epoch 2/200
# 270/270 [==============================] - 1s 4ms/step - loss: 6654.6079 - mae: 6654.6079
# Epoch 3/200
# 270/270 [==============================] - 1s 5ms/step - loss: 6571.0747 - mae: 6571.0747
# Epoch 4/200
# 270/270 [==============================] - 2s 7ms/step - loss: 6450.6924 - mae: 6450.6924
# Epoch 5/200
# 270/270 [==============================] - 2s 8ms/step - loss: 6293.9409 - mae: 6293.9409
# Epoch 6/200
# 270/270 [==============================] - 2s 6ms/step - loss: 6107.8564 - mae: 6107.8564
# Epoch 7/200
# 270/270 [==============================] - 1s 4ms/step - loss: 5889.7275 - mae: 5889.7275
# Epoch 8/200
# ...

# %%
y_hat_jan_1990 = model.predict(jan_1990_test_X_norm)
# Out:
# 23/23 [==============================] - 0s 2ms/step

# %%
y_hat_jan_1990
# Out:
# array([[5685.0405],
#        [5240.0996],
#        [4904.5703],
#        [4730.554 ],
#        [4707.6294],
#        [4847.26  ],
#        [4929.579 ],
#        [5360.974 ],
#        [6295.6616],
#        [7131.335 ],
#        [7649.197 ],
#        [7837.7944],
#        [7837.7944],
#        [7766.9404],
#        [7641.9023],
#        [7655.4487],
#        [7810.7036],
#        [8645.325 ],
#        [8656.787 ],
#        [8281.677 ],
#        [7760.6885],
#        [7220.9453],
#        [6590.5503],
#        [5839.259 ],
#        [4142.8555],
#        [3931.3271],
#        [3924.0332],
#        [3987.5964],
#        [4307.493 ],
#        [5333.8726],
#        [6645.7637],
#        [7311.6094],
#        [7577.322 ],
#        [7405.3906],
#        [7174.0635],
#        [6965.662 ],
#        [6753.092 ],
#        [6515.5127],
#        [6485.2954],
#        [6534.269 ],
#        [6747.881 ],
#        [7735.7075],
#        [7848.245 ],
#        [7373.0874],
#        [6748.923 ],
# ...

# %%
jan_1990_test_y
# Out:
# array([5118, 4915, 4908, 4969, 5276, 6261, 7520, 8159, 8414, 8249, 8027,
#        7827, 7623, 7395, 7366, 7413, 7618, 8566, 8674, 8218, 7619, 6962,
#        6188, 5320, 4839, 4659, 4587, 4622, 4871, 5802, 7033, 7557, 7678,
#        7791, 7771, 7806, 7772, 7705, 7653, 7704, 7882, 8734, 8811, 8382,
#        7777, 7110, 6339, 5486, 4980, 4771, 4650, 4688, 4889, 5748, 6918,
#        7465, 7819, 8049, 8123, 8150, 8135, 8051, 8003, 8062, 8280, 9066,
#        9211, 8744, 8129, 7426, 6560, 5722, 5135, 4876, 4748, 4721, 4858,
#        5677, 6798, 7454, 7989, 8422, 8565, 8662, 8617, 8646, 8680, 8702,
#        8654, 9181, 9252, 8655, 8066, 7453, 6803, 5943, 5367, 5043, 4830,
#        4723, 4791, 4994, 5420, 6245, 7278, 7981, 8308, 8403, 8423, 8343,
#        8342, 8352, 8454, 9031, 9109, 8505, 7916, 7413, 6769, 6019, 5390,
#        5023, 4795, 4735, 4745, 4863, 5120, 5704, 6616, 7279, 7624, 7887,
#        8016, 8026, 8021, 8041, 8143, 8648, 8744, 8355, 7775, 7190, 6374,
# ...

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(jan_1990_test_y, y_hat_jan_1990)
# Out:
# 639.9100453694662

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(jan_1990_test_y, y_hat_jan_1990)
# Out:
# 0.09356518093797216

# %%
jan_forcast = pd.DataFrame()

# %%
jan_forcast['True_Load'] = jan_1990_test_y
jan_forcast['Pred_Load'] = y_hat_jan_1990

# %%
jan_forcast
# Out:
#      True_Load    Pred_Load
# 0         5118  5685.040527
# 1         4915  5240.099609
# 2         4908  4904.570312
# 3         4969  4730.554199
# 4         5276  4707.629395
# ..         ...          ...
# 715       9341  9091.411133
# 716       8687  8311.988281
# 717       7917  7521.101074
# 718       6994  6588.501953
# 719       6068  5560.036621
#
# [720 rows x 2 columns]

# %%
jan_forcast.to_csv("Predictions/jan.csv")

# %%
plot_ytrue_yhat(jan_1990_test_y, y_hat_jan_1990)

# %% [markdown]
# ### February Forecast

# %%
jan_1990_test = final_df_1990_ANN1[:744]
jan_1990_test = jan_1990_test.dropna()

# %%
feb_1990_train_frames = [jan_feb_1987,nov_dec_1987, jan_feb_1988, nov_dec_1988, jan_feb_1989, nov_dec_1989, jan_1990_test]
feb_1990_train = pd.concat(feb_1990_train_frames)

# %%
feb_1990_train
# Out:
#      daytype    AvgL(k-1)  sqr[maxL(k-1)-AveL(k-1)]  sqr[aveL(k-1)-minL(k-1)]  \
# 24     0.500  5248.291667               1746912.918               2305209.585
# 25     0.500  5248.291667               1746912.918               2305209.585
# 26     0.500  5248.291667               1746912.918               2305209.585
# 27     0.500  5248.291667               1746912.918               2305209.585
# 28     0.500  5248.291667               1746912.918               2305209.585
# ..       ...          ...                       ...                       ...
# 739    0.625  7576.916667               5410663.674               8002769.507
# 740    0.625  7576.916667               5410663.674               8002769.507
# 741    0.625  7576.916667               5410663.674               8002769.507
# 742    0.625  7576.916667               5410663.674               8002769.507
# 743    0.625  7576.916667               5410663.674               8002769.507
#
# ...

# %%
feb_1990_test = final_df_1990_ANN1[744:1416]
feb_1990_test
# Out:
#       daytype    AvgL(k-1)  sqr[maxL(k-1)-AveL(k-1)]  \
# 744     0.750  7668.458333               5274103.627
# 745     0.750  7668.458333               5274103.627
# 746     0.750  7668.458333               5274103.627
# 747     0.750  7668.458333               5274103.627
# 748     0.750  7668.458333               5274103.627
# ...       ...          ...                       ...
# 1411    0.625  6687.083333               3086756.174
# 1412    0.625  6687.083333               3086756.174
# 1413    0.625  6687.083333               3086756.174
# 1414    0.625  6687.083333               3086756.174
# 1415    0.625  6687.083333               3086756.174
#
#       sqr[aveL(k-1)-minL(k-1)]  L(k-1,8)  L(l-1,h)  hourtype  Load
# 744                7825773.127    7571.0    5353.0  0.000000  5424
# 745                7825773.127    7571.0    5052.0  0.043478  5155
# 746                7825773.127    7571.0    4944.0  0.086957  5032
# ...

# %%
daytype_train_feb = feb_1990_train['daytype']
daytype_test_feb = feb_1990_test['daytype']

# %%
hourtype_train = feb_1990_train['hourtype']
hourtype_test = feb_1990_test['hourtype']

# %%
feb_1990_train.drop(columns = ['daytype','hourtype'], inplace = True)
feb_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)
# Out:
# C:\Users\ketul\AppData\Local\Temp\ipykernel_1156\2772470961.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feb_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
feb_1990_train_X = feb_1990_train.iloc[:, :5]
feb_1990_train_y = feb_1990_train['Load']

feb_1990_test_X = feb_1990_test.iloc[:, :5]
feb_1990_test_y = feb_1990_test['Load']

# %%
feb_1990_train_y = feb_1990_train_y.values
feb_1990_test_y = feb_1990_test_y.values

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

feb_1990_train_X_norm = scaler.fit_transform(feb_1990_train_X)
feb_1990_test_X_norm = scaler.fit_transform(feb_1990_test_X)

# %%
daytype_train_feb = daytype_train_feb.values
daytype_train_feb =  daytype_train_feb.reshape(-1,1)

daytype_test_feb = daytype_test_feb.values
daytype_test_feb =  daytype_test_feb.reshape(-1,1)

hourtype_train = hourtype_train.values
hourtype_train = hourtype_train.reshape(-1,1)

hourtype_test = hourtype_test.values
hourtype_test = hourtype_test.reshape(-1,1)

feb_1990_train_X_norm = np.hstack((feb_1990_train_X_norm, daytype_train_feb, hourtype_train))
feb_1990_test_X_norm = np.hstack((feb_1990_test_X_norm, daytype_test_feb, hourtype_test))

# %%
model_feb = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation = tf.keras.activations.relu),
  tf.keras.layers.Dropout(0.1),
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model_feb.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.0002),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model_feb.fit(feb_1990_train_X_norm, feb_1990_train_y, epochs=500)
# Out:
# Epoch 1/500
# C:\Users\ketul\anaconda3\envs\TensorflowGPU\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 292/292 [==============================] - 1s 3ms/step - loss: 6731.1978 - mae: 6731.1978
# Epoch 2/500
# 292/292 [==============================] - 1s 3ms/step - loss: 6730.3740 - mae: 6730.3740
# Epoch 3/500
# 292/292 [==============================] - 1s 3ms/step - loss: 6729.3975 - mae: 6729.3975
# Epoch 4/500
# 292/292 [==============================] - 1s 3ms/step - loss: 6728.2246 - mae: 6728.2246
# Epoch 5/500
# 292/292 [==============================] - 1s 3ms/step - loss: 6726.8770 - mae: 6726.8770
# Epoch 6/500
# 292/292 [==============================] - 1s 3ms/step - loss: 6725.3506 - mae: 6725.3506
# Epoch 7/500
# 292/292 [==============================] - 1s 3ms/step - loss: 6723.6387 - mae: 6723.6387
# Epoch 8/500
# ...

# %%
y_hat_feb_1990 = model_feb.predict(feb_1990_test_X_norm)

y_hat_feb_1990
# Out:
# 21/21 [==============================] - 0s 1ms/step
# array([[ 5148.1016],
#        [ 5112.388 ],
#        [ 5183.6665],
#        [ 5274.3467],
#        [ 5502.5103],
#        [ 6094.3345],
#        [ 6885.7305],
#        [ 7295.723 ],
#        [ 7696.293 ],
#        [ 8106.8403],
#        [ 8328.904 ],
#        [ 8538.773 ],
#        [ 8719.815 ],
#        [ 8864.824 ],
#        [ 9076.911 ],
#        [ 9245.756 ],
#        [ 9440.104 ],
#        [ 9679.908 ],
#        [10065.509 ],
#        [ 9850.736 ],
#        [ 9619.332 ],
#        [ 9323.623 ],
#        [ 8943.096 ],
#        [ 8560.905 ],
#        [ 3396.3843],
#        [ 3378.4102],
#        [ 3441.373 ],
#        [ 3568.6418],
#        [ 3787.9348],
#        [ 4378.6504],
#        [ 5188.3394],
#        [ 5644.345 ],
#        [ 6058.2197],
#        [ 6397.809 ],
#        [ 6645.374 ],
#        [ 6799.253 ],
#        [ 7016.8823],
#        [ 7155.238 ],
#        [ 7354.0205],
#        [ 7531.181 ],
#        [ 7706.679 ],
# ...

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(feb_1990_test_y, y_hat_feb_1990)
# Out:
# 975.103409176781

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(feb_1990_test_y, y_hat_feb_1990)
# Out:
# 0.14007234494982732

# %%
feb_forcast = pd.DataFrame()

feb_forcast['True_Load'] = feb_1990_test_y
feb_forcast['Pred_Load'] = y_hat_feb_1990

feb_forcast
# Out:
#      True_Load    Pred_Load
# 0         5424  5148.101562
# 1         5155  5112.388184
# 2         5032  5183.666504
# 3         5025  5274.346680
# 4         5184  5502.510254
# ..         ...          ...
# 667       8118  8040.064453
# 668       7548  7811.432617
# 669       6849  7556.190918
# 670       6056  7248.838867
# 671       5157  7090.458008
#
# [672 rows x 2 columns]

# %%
feb_forcast.to_csv("Predictions/feb.csv")

# %%
plot_ytrue_yhat(feb_1990_test_y, y_hat_feb_1990)

# %% [markdown]
# ### November Forecast

# %%
jan_feb_1990 = final_df_1990_ANN1[:1416]
jan_feb_1990 = jan_feb_1990.dropna()

# %%
nov_1990_train_frames = [jan_feb_1987,nov_dec_1987, jan_feb_1988, nov_dec_1988,jan_feb_1989, nov_dec_1989, jan_feb_1990]
nov_1990_train = pd.concat(nov_1990_train_frames)

# %%
nov_1990_test = final_df_1990_ANN1[7296:8016]
nov_1990_test
# Out:
#       daytype    AvgL(k-1)  sqr[maxL(k-1)-AveL(k-1)]  \
# 7296     0.75  7231.291667               2936796.252
# 7297     0.75  7231.291667               2936796.252
# 7298     0.75  7231.291667               2936796.252
# 7299     0.75  7231.291667               2936796.252
# 7300     0.75  7231.291667               2936796.252
# ...       ...          ...                       ...
# 8011     0.00  8200.958333               4791903.418
# 8012     0.00  8200.958333               4791903.418
# 8013     0.00  8200.958333               4791903.418
# 8014     0.00  8200.958333               4791903.418
# 8015     0.00  8200.958333               4791903.418
#
#       sqr[aveL(k-1)-minL(k-1)]  L(k-1,8)  L(l-1,h)  hourtype  Load
# 7296               5732632.585    7438.0    5173.0  0.000000  5158
# 7297               5732632.585    7438.0    4926.0  0.043478  4927
# 7298               5732632.585    7438.0    4855.0  0.086957  4837
# ...

# %%
daytype_train_nov = nov_1990_train['daytype']
daytype_test_nov = nov_1990_test['daytype']

hourtype_train = nov_1990_train['hourtype']
hourtype_test = nov_1990_test['hourtype']

nov_1990_train.drop(columns = ['daytype','hourtype'], inplace = True)
nov_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

nov_1990_train_X = nov_1990_train.iloc[:, :5]
nov_1990_train_y = nov_1990_train['Load']

nov_1990_test_X = nov_1990_test.iloc[:, :5]
nov_1990_test_y = nov_1990_test['Load']

nov_1990_train_y = nov_1990_train_y.values
nov_1990_test_y = nov_1990_test_y.values
# Out:
# C:\Users\ketul\AppData\Local\Temp\ipykernel_1156\1749038618.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

nov_1990_train_X_norm = scaler.fit_transform(nov_1990_train_X)
nov_1990_test_X_norm = scaler.fit_transform(nov_1990_test_X)

daytype_train_nov = daytype_train_nov.values
daytype_train_nov =  daytype_train_nov.reshape(-1,1)

daytype_test_nov = daytype_test_nov.values
daytype_test_nov =  daytype_test_nov.reshape(-1,1)

hourtype_train = hourtype_train.values
hourtype_train = hourtype_train.reshape(-1,1)

hourtype_test = hourtype_test.values
hourtype_test = hourtype_test.reshape(-1,1)

nov_1990_train_X_norm = np.hstack((nov_1990_train_X_norm, daytype_train_nov,hourtype_train))
nov_1990_test_X_norm = np.hstack((nov_1990_test_X_norm, daytype_test_nov, hourtype_test))

# %%
model_nov = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation = tf.keras.activations.relu),
  tf.keras.layers.Dropout(0.1),
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model_nov.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.002),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model_nov.fit(nov_1990_train_X_norm, nov_1990_train_y, epochs=500)
# Out:
# Epoch 1/500
# C:\Users\ketul\anaconda3\envs\TensorflowGPU\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 313/313 [==============================] - 1s 3ms/step - loss: 6753.5737 - mae: 6753.5737
# Epoch 2/500
# 313/313 [==============================] - 1s 3ms/step - loss: 6715.6289 - mae: 6715.6289
# Epoch 3/500
# 313/313 [==============================] - 1s 3ms/step - loss: 6641.2676 - mae: 6641.2676
# Epoch 4/500
# 313/313 [==============================] - 1s 3ms/step - loss: 6534.7783 - mae: 6534.7783
# Epoch 5/500
# 313/313 [==============================] - 1s 3ms/step - loss: 6398.1074 - mae: 6398.1074
# Epoch 6/500
# 313/313 [==============================] - 1s 3ms/step - loss: 6236.9321 - mae: 6236.9321
# Epoch 7/500
# 313/313 [==============================] - 1s 3ms/step - loss: 6049.6860 - mae: 6049.6860
# Epoch 8/500
# ...

# %%
y_hat_nov_1990 = model_nov.predict(nov_1990_test_X_norm)

y_hat_nov_1990
# Out:
# 23/23 [==============================] - 0s 1ms/step
# array([[4413.542 ],
#        [4215.6772],
#        [4168.542 ],
#        [4166.797 ],
#        [4344.043 ],
#        [5059.977 ],
#        [5971.175 ],
#        [6449.024 ],
#        [6880.627 ],
#        [7177.772 ],
#        [7325.901 ],
#        [7402.089 ],
#        [7427.749 ],
#        [7465.401 ],
#        [7503.0503],
#        [7526.998 ],
#        [7496.1353],
#        [7876.3525],
#        [7702.4673],
#        [7359.0117],
#        [6939.334 ],
#        [6393.763 ],
#        [5660.6367],
#        [5078.2393],
#        [4761.05  ],
#        [4576.8877],
#        [4513.4805],
#        [4491.1816],
#        [4677.849 ],
#        [5380.936 ],
#        [6228.7583],
#        [6773.409 ],
#        [7246.976 ],
#        [7556.9673],
#        [7781.3164],
#        [7901.1836],
#        [7968.808 ],
#        [8032.151 ],
#        [8056.099 ],
#        [8047.502 ],
#        [8062.886 ],
#        [8558.72  ],
# ...

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(nov_1990_test_y, y_hat_nov_1990)
# Out:
# 724.6256483289931

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(nov_1990_test_y, y_hat_nov_1990)
# Out:
# 0.09864250558269269

# %%
nov_forcast = pd.DataFrame()

nov_forcast['True_Load'] = nov_1990_test_y
nov_forcast['Pred_Load'] = y_hat_nov_1990

nov_forcast
# Out:
#      True_Load    Pred_Load
# 0         5158  4413.541992
# 1         4927  4215.677246
# 2         4837  4168.541992
# 3         4795  4166.796875
# 4         4997  4344.042969
# ..         ...          ...
# 715       7767  8649.977539
# 716       7354  8101.836914
# 717       6835  7439.793457
# 718       6145  6587.625000
# 719       5530  5747.446289
#
# [720 rows x 2 columns]

# %%
nov_forcast.to_csv("Predictions/nov.csv")

# %%
plot_ytrue_yhat(nov_1990_test_y, y_hat_nov_1990)

# %% [markdown]
# ### December Forecasting

# %%
nov_1990 = final_df_1990_ANN1[7296:8016]

# %%
dec_1990_train_frames = [nov_dec_1987, jan_feb_1988, nov_dec_1988,jan_feb_1989, nov_dec_1989, jan_feb_1990,nov_1990]
dec_1990_train = pd.concat(dec_1990_train_frames)

# %%
dec_1990_test = final_df_1990_ANN1[8016:8760]
dec_1990_test
# Out:
#       daytype    AvgL(k-1)  sqr[maxL(k-1)-AveL(k-1)]  \
# 8016    0.125  7035.458333               2215756.293
# 8017    0.125  7035.458333               2215756.293
# 8018    0.125  7035.458333               2215756.293
# 8019    0.125  7035.458333               2215756.293
# 8020    0.125  7035.458333               2215756.293
# ...       ...          ...                       ...
# 8755    0.375  7179.916667               3798925.840
# 8756    0.375  7179.916667               3798925.840
# 8757    0.375  7179.916667               3798925.840
# 8758    0.375  7179.916667               3798925.840
# 8759    0.375  7179.916667               3798925.840
#
#       sqr[aveL(k-1)-minL(k-1)]  L(k-1,8)  L(l-1,h)  hourtype  Load
# 8016                4249610.46    7648.0    5588.0  0.000000  4989
# 8017                4249610.46    7648.0    5250.0  0.043478  4776
# 8018                4249610.46    7648.0    5065.0  0.086957  4660
# ...

# %%
daytype_train_dec = dec_1990_train['daytype']
daytype_test_dec = dec_1990_test['daytype']

hourtype_train = dec_1990_train['hourtype']
hourtype_test = dec_1990_test['hourtype']

dec_1990_train.drop(columns = ['daytype','hourtype'], inplace = True)
dec_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

dec_1990_train_X = dec_1990_train.iloc[:, :5]
dec_1990_train_y = dec_1990_train['Load']

dec_1990_test_X = dec_1990_test.iloc[:, :5]
dec_1990_test_y = dec_1990_test['Load']

dec_1990_train_y = dec_1990_train_y.values
dec_1990_test_y = dec_1990_test_y.values
# Out:
# C:\Users\ketul\AppData\Local\Temp\ipykernel_1156\1772156208.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dec_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

dec_1990_train_X_norm = scaler.fit_transform(dec_1990_train_X)
dec_1990_test_X_norm = scaler.fit_transform(dec_1990_test_X)

daytype_train_dec = daytype_train_dec.values
daytype_train_dec =  daytype_train_dec.reshape(-1,1)

daytype_test_dec = daytype_test_dec.values
daytype_test_dec =  daytype_test_dec.reshape(-1,1)

hourtype_train = hourtype_train.values
hourtype_train = hourtype_train.reshape(-1,1)

hourtype_test = hourtype_test.values
hourtype_test = hourtype_test.reshape(-1,1)

dec_1990_train_X_norm = np.hstack((dec_1990_train_X_norm, daytype_train_dec,hourtype_train))
dec_1990_test_X_norm = np.hstack((dec_1990_test_X_norm, daytype_test_dec, hourtype_test))

# %%
model_dec = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model_dec.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.002),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model_dec.fit(dec_1990_train_X_norm, dec_1990_train_y, epochs=350)
# Out:
# Epoch 1/350
# C:\Users\ketul\anaconda3\envs\TensorflowGPU\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 292/292 [==============================] - 1s 3ms/step - loss: 6868.2407 - mae: 6868.2407
# Epoch 2/350
# 292/292 [==============================] - 1s 3ms/step - loss: 6839.2188 - mae: 6839.2188
# Epoch 3/350
# 292/292 [==============================] - 1s 3ms/step - loss: 6780.2314 - mae: 6780.2314
# Epoch 4/350
# 292/292 [==============================] - 1s 3ms/step - loss: 6688.0806 - mae: 6688.0806
# Epoch 5/350
# 292/292 [==============================] - 1s 3ms/step - loss: 6568.9849 - mae: 6568.9849
# Epoch 6/350
# 292/292 [==============================] - 1s 3ms/step - loss: 6426.2256 - mae: 6426.2256
# Epoch 7/350
# 292/292 [==============================] - 1s 3ms/step - loss: 6261.6982 - mae: 6261.6982
# Epoch 8/350
# ...

# %%
y_hat_dec_1990 = model_dec.predict(dec_1990_test_X_norm)

y_hat_dec_1990
# Out:
# 24/24 [==============================] - 0s 1ms/step
# array([[ 4979.3213],
#        [ 4628.54  ],
#        [ 4440.242 ],
#        [ 4351.77  ],
#        [ 4538.343 ],
#        [ 5437.4937],
#        [ 6690.2793],
#        [ 7224.1133],
#        [ 7602.901 ],
#        [ 7784.163 ],
#        [ 7830.554 ],
#        [ 7782.432 ],
#        [ 7600.5015],
#        [ 7499.2793],
#        [ 7355.58  ],
#        [ 7346.75  ],
#        [ 7548.1895],
#        [ 8236.008 ],
#        [ 7974.43  ],
#        [ 7448.423 ],
#        [ 7017.992 ],
#        [ 6474.993 ],
#        [ 5750.398 ],
#        [ 5105.4497],
#        [ 4783.8   ],
#        [ 4565.7627],
#        [ 4450.736 ],
#        [ 4410.0464],
#        [ 4559.449 ],
#        [ 4843.7217],
#        [ 5391.362 ],
#        [ 6308.566 ],
#        [ 6950.721 ],
#        [ 7316.7656],
#        [ 7454.4863],
#        [ 7446.7183],
#        [ 7390.0996],
#        [ 7265.514 ],
#        [ 7093.141 ],
#        [ 7101.3037],
#        [ 7322.92  ],
# ...

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(dec_1990_test_y, y_hat_dec_1990)
# Out:
# 447.35843322097617

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(dec_1990_test_y, y_hat_dec_1990)
# Out:
# 0.06569055082294194

# %%
dec_forcast = pd.DataFrame()

dec_forcast['True_Load'] = dec_1990_test_y
dec_forcast['Pred_Load'] = y_hat_dec_1990

dec_forcast
# Out:
#      True_Load    Pred_Load
# 0         4989  4979.321289
# 1         4776  4628.540039
# 2         4660  4440.242188
# 3         4614  4351.770020
# 4         4747  4538.342773
# ..         ...          ...
# 739       8998  8751.440430
# 740       8195  8237.115234
# 741       7530  7656.947266
# 742       6951  6914.298828
# 743       6357  6022.974121
#
# [744 rows x 2 columns]

# %%
dec_forcast.to_csv("Predictions/dec.csv")

# %%
plot_ytrue_yhat(dec_1990_test_y, y_hat_dec_1990)

# %% [markdown]
# ### April Forecast

# %%
apr_sep_1987 = final_df_ANN2[2160:6552]
apr_sep_1987
# Out:
#       daytype  L(l-1,h)  L(k-1,24)  Max L(k-1)  Min L(k-1)  hourtype  Load
# 2160     0.25    4930.0     6721.0      7698.0      4400.0  0.000000  5121
# 2161     0.25    4643.0     6721.0      7698.0      4400.0  0.043478  5062
# 2162     0.25    4509.0     6721.0      7698.0      4400.0  0.086957  5103
# 2163     0.25    4453.0     6721.0      7698.0      4400.0  0.130435  5220
# 2164     0.25    4400.0     6721.0      7698.0      4400.0  0.173913  5622
# ...       ...       ...        ...         ...         ...       ...   ...
# 6547     0.25    9925.0     9318.0     10329.0      5040.0  0.826087  9136
# 6548     0.25    9158.0     9318.0     10329.0      5040.0  0.869565  8565
# 6549     0.25    8350.0     9318.0     10329.0      5040.0  0.913043  7873
# 6550     0.25    7443.0     9318.0     10329.0      5040.0  0.956522  7110
# 6551     0.25    6569.0     9318.0     10329.0      5040.0  1.000000  6296
#
# [4392 rows x 7 columns]

# %%
apr_sep_1988 = final_df_ANN2[10920:15312]
apr_sep_1988
# Out:
#        daytype  L(l-1,h)  L(k-1,24)  Max L(k-1)  Min L(k-1)  hourtype   Load
# 10920    0.375    4677.0     8034.0      8506.0      4308.0  0.000000   4784
# 10921    0.375    4391.0     8034.0      8506.0      4308.0  0.043478   4507
# 10922    0.375    4308.0     8034.0      8506.0      4308.0  0.086957   4378
# 10923    0.375    4325.0     8034.0      8506.0      4308.0  0.130435   4337
# 10924    0.375    4459.0     8034.0      8506.0      4308.0  0.173913   4493
# ...        ...       ...        ...         ...         ...       ...    ...
# 15307    0.375   10885.0    10060.0     11502.0      5735.0  0.826087  10875
# 15308    0.375   10083.0    10060.0     11502.0      5735.0  0.869565  10212
# 15309    0.375    9136.0    10060.0     11502.0      5735.0  0.913043   9232
# 15310    0.375    8178.0    10060.0     11502.0      5735.0  0.956522   8298
# 15311    0.375    7111.0    10060.0     11502.0      5735.0  1.000000   7296
#
# [4392 rows x 7 columns]

# %%
apr_sep_1989 = final_df_ANN2[19680:24072]
apr_sep_1989
# Out:
#        daytype  L(l-1,h)  L(k-1,24)  Max L(k-1)  Min L(k-1)  hourtype   Load
# 19680      0.5    5700.0     9497.0      9497.0      5152.0  0.000000   5557
# 19681      0.5    5424.0     9497.0      9497.0      5152.0  0.043478   5182
# 19682      0.5    5226.0     9497.0      9497.0      5152.0  0.086957   4981
# 19683      0.5    5152.0     9497.0      9497.0      5152.0  0.130435   4898
# 19684      0.5    5292.0     9497.0      9497.0      5152.0  0.173913   4896
# ...        ...       ...        ...         ...         ...       ...    ...
# 24067      0.5   11585.0    11470.0     12466.0      6858.0  0.826087  11214
# 24068      0.5   10823.0    11470.0     12466.0      6858.0  0.869565  10553
# 24069      0.5   10078.0    11470.0     12466.0      6858.0  0.913043   9853
# 24070      0.5    9282.0    11470.0     12466.0      6858.0  0.956522   9055
# 24071      0.5    8389.0    11470.0     12466.0      6858.0  1.000000   8217
#
# [4392 rows x 7 columns]

# %%
apr_1990_train_frames = [apr_sep_1987, apr_sep_1988, apr_sep_1989]
apr_1990_train = pd.concat(apr_1990_train_frames)

# %%
apr_1990_test = final_df_1990_ANN2[2160:2880]
apr_1990_test
# Out:
#       daytype  L(l-1,h)  L(k-1,24)  Max L(k-1)  Min L(k-1)  hourtype  Load
# 2160    0.250    5870.0     8703.0      8703.0      5244.0  0.000000  5200
# 2161    0.250    5547.0     8703.0      8703.0      5244.0  0.043478  4950
# 2162    0.250    5312.0     8703.0      8703.0      5244.0  0.086957  4940
# 2163    0.250    5244.0     8703.0      8703.0      5244.0  0.130435  4816
# 2164    0.250    5310.0     8703.0      8703.0      5244.0  0.173913  4700
# ...       ...       ...        ...         ...         ...       ...   ...
# 2875    0.375    8817.0     8401.0      9035.0      5013.0  0.826087  9981
# 2876    0.375    8949.0     8401.0      9035.0      5013.0  0.869565  9854
# 2877    0.375    8294.0     8401.0      9035.0      5013.0  0.913043  8818
# 2878    0.375    7359.0     8401.0      9035.0      5013.0  0.956522  7678
# 2879    0.375    6473.0     8401.0      9035.0      5013.0  1.000000  6593
#
# [720 rows x 7 columns]

# %%
daytype_train_apr = apr_1990_train['daytype']
daytype_test_apr = apr_1990_test['daytype']

hourtype_train = apr_1990_train['hourtype']
hourtype_test = apr_1990_test['hourtype']

apr_1990_train.drop(columns = ['daytype','hourtype'], inplace = True)
apr_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

apr_1990_train_X = apr_1990_train.iloc[:, :5]
apr_1990_train_y = apr_1990_train['Load']

apr_1990_test_X = apr_1990_test.iloc[:, :5]
apr_1990_test_y = apr_1990_test['Load']

apr_1990_train_y = apr_1990_train_y.values
apr_1990_test_y = apr_1990_test_y.values
# Out:
# C:\Users\ketul\AppData\Local\Temp\ipykernel_1156\3330898728.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apr_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

apr_1990_train_X_norm = scaler.fit_transform(apr_1990_train_X)
apr_1990_test_X_norm = scaler.fit_transform(apr_1990_test_X)

daytype_train_apr = daytype_train_apr.values
daytype_train_apr =  daytype_train_apr.reshape(-1,1)

daytype_test_apr = daytype_test_apr.values
daytype_test_apr =  daytype_test_apr.reshape(-1,1)

hourtype_train = hourtype_train.values
hourtype_train = hourtype_train.reshape(-1,1)

hourtype_test = hourtype_test.values
hourtype_test = hourtype_test.reshape(-1,1)

apr_1990_train_X_norm = np.hstack((apr_1990_train_X_norm, daytype_train_apr,hourtype_train))
apr_1990_test_X_norm = np.hstack((apr_1990_test_X_norm, daytype_test_apr, hourtype_test))

# %%
model_apr = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation = tf.keras.activations.relu),
  tf.keras.layers.Dropout(0.2),  
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model_apr.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.002),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model_apr.fit(apr_1990_train_X_norm, apr_1990_train_y, epochs=300)
# Out:
# Epoch 1/300
# C:\Users\ketul\anaconda3\envs\TensorflowGPU\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 412/412 [==============================] - 1s 3ms/step - loss: 8218.6738 - mae: 8218.6738
# Epoch 2/300
# 412/412 [==============================] - 1s 3ms/step - loss: 8153.2876 - mae: 8153.2876
# Epoch 3/300
# 412/412 [==============================] - 1s 3ms/step - loss: 8027.1968 - mae: 8027.1968
# Epoch 4/300
# 412/412 [==============================] - 1s 3ms/step - loss: 7850.7129 - mae: 7850.7129
# Epoch 5/300
# 412/412 [==============================] - 1s 3ms/step - loss: 7627.4438 - mae: 7627.4438
# Epoch 6/300
# 412/412 [==============================] - 1s 3ms/step - loss: 7362.8071 - mae: 7362.8071
# Epoch 7/300
# 412/412 [==============================] - 1s 3ms/step - loss: 7057.6450 - mae: 7057.6450
# Epoch 8/300
# ...

# %%
y_hat_apr_1990 = model_apr.predict(apr_1990_test_X_norm)

y_hat_apr_1990
# Out:
# 23/23 [==============================] - 0s 2ms/step
# array([[ 5201.9937],
#        [ 4891.5894],
#        [ 4879.1885],
#        [ 4725.2104],
#        [ 4581.1484],
#        [ 4705.284 ],
#        [ 4953.5547],
#        [ 5450.1064],
#        [ 6443.3276],
#        [ 7374.529 ],
#        [ 8057.4556],
#        [ 8429.958 ],
#        [ 8740.389 ],
#        [ 8926.688 ],
#        [ 9112.982 ],
#        [ 9299.254 ],
#        [ 9485.501 ],
#        [ 9547.561 ],
#        [ 9299.134 ],
#        [ 9547.496 ],
#        [ 9423.38  ],
#        [ 8616.317 ],
#        [ 7498.8276],
#        [ 6381.35  ],
#        [ 5549.2124],
#        [ 5132.0107],
#        [ 4878.6875],
#        [ 4848.888 ],
#        [ 4908.4927],
#        [ 5749.1147],
#        [ 7167.127 ],
#        [ 7854.98  ],
#        [ 8673.164 ],
#        [ 9362.215 ],
#        [ 9789.287 ],
#        [ 9900.992 ],
#        [10292.091 ],
#        [10515.57  ],
#        [10724.148 ],
#        [10907.893 ],
#        [10958.7705],
# ...

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(apr_1990_test_y, y_hat_apr_1990)
# Out:
# 514.2178161621093

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(apr_1990_test_y, y_hat_apr_1990)
# Out:
# 0.0640097068242251

# %%
apr_forcast = pd.DataFrame()

apr_forcast['True_Load'] = apr_1990_test_y
apr_forcast['Pred_Load'] = y_hat_apr_1990

apr_forcast
# Out:
#      True_Load     Pred_Load
# 0         5200   5201.993652
# 1         4950   4891.589355
# 2         4940   4879.188477
# 3         4816   4725.210449
# 4         4700   4581.148438
# ..         ...           ...
# 715       9981  11137.943359
# 716       9854  10980.215820
# 717       8818   9693.857422
# 718       7678   8278.394531
# 719       6593   6931.220215
#
# [720 rows x 2 columns]

# %%
plot_ytrue_yhat(apr_1990_test_y, y_hat_apr_1990)

# %%
apr_forcast.to_csv("Predictions/apr.csv")

# %% [markdown]
# ### May Forecast

# %%
april_1990 = final_df_1990_ANN2[2160:2880]
may_1990_train_frames = [apr_sep_1987, apr_sep_1988, apr_sep_1989, april_1990]
may_1990_train = pd.concat(may_1990_train_frames)

# %%
may_1990_test = final_df_1990_ANN2[2880:3624]
may_1990_test
# Out:
#       daytype  L(l-1,h)  L(k-1,24)  Max L(k-1)  Min L(k-1)  hourtype   Load
# 2880     0.50    5891.0     9670.0     10714.0      5165.0  0.000000   5865
# 2881     0.50    5481.0     9670.0     10714.0      5165.0  0.043478   5572
# 2882     0.50    5245.0     9670.0     10714.0      5165.0  0.086957   5346
# 2883     0.50    5165.0     9670.0     10714.0      5165.0  0.130435   5194
# 2884     0.50    5280.0     9670.0     10714.0      5165.0  0.173913   5305
# ...       ...       ...        ...         ...         ...       ...    ...
# 3619     0.75   10477.0    10852.0     11412.0      6215.0  0.826087  10794
# 3620     0.75   10521.0    10852.0     11412.0      6215.0  0.869565  10807
# 3621     0.75    9735.0    10852.0     11412.0      6215.0  0.913043   9929
# 3622     0.75    8634.0    10852.0     11412.0      6215.0  0.956522   8817
# 3623     0.75    7539.0    10852.0     11412.0      6215.0  1.000000   7812
#
# [744 rows x 7 columns]

# %%
daytype_train_may = may_1990_train['daytype']
daytype_test_may = may_1990_test['daytype']

hourtype_train = may_1990_train['hourtype']
hourtype_test = may_1990_test['hourtype']

may_1990_train.drop(columns = ['daytype','hourtype'], inplace = True)
may_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

may_1990_train_X = may_1990_train.iloc[:, :5]
may_1990_train_y = may_1990_train['Load']

may_1990_test_X = may_1990_test.iloc[:, :5]
may_1990_test_y = may_1990_test['Load']

may_1990_train_y = may_1990_train_y.values
may_1990_test_y = may_1990_test_y.values
# Out:
# C:\Users\ketul\AppData\Local\Temp\ipykernel_1156\1475366386.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   may_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

may_1990_train_X_norm = scaler.fit_transform(may_1990_train_X)
may_1990_test_X_norm = scaler.fit_transform(may_1990_test_X)

daytype_train_may = daytype_train_may.values
daytype_train_may =  daytype_train_may.reshape(-1,1)

daytype_test_may = daytype_test_may.values
daytype_test_may =  daytype_test_may.reshape(-1,1)

hourtype_train = hourtype_train.values
hourtype_train = hourtype_train.reshape(-1,1)

hourtype_test = hourtype_test.values
hourtype_test = hourtype_test.reshape(-1,1)

may_1990_train_X_norm = np.hstack((may_1990_train_X_norm, daytype_train_may,hourtype_train))
may_1990_test_X_norm = np.hstack((may_1990_test_X_norm, daytype_test_may, hourtype_test))

# %%
model_may = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model_may.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.002),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model_may.fit(may_1990_train_X_norm, may_1990_train_y, epochs=300)
# Out:
# Epoch 1/300
# C:\Users\ketul\anaconda3\envs\TensorflowGPU\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 435/435 [==============================] - 2s 4ms/step - loss: 8165.2153 - mae: 8165.2153
# Epoch 2/300
# 435/435 [==============================] - 1s 3ms/step - loss: 8093.4897 - mae: 8093.4897
# Epoch 3/300
# 435/435 [==============================] - 1s 3ms/step - loss: 7952.9038 - mae: 7952.9038
# Epoch 4/300
# 435/435 [==============================] - 2s 4ms/step - loss: 7753.8672 - mae: 7753.8672
# Epoch 5/300
# 435/435 [==============================] - 1s 3ms/step - loss: 7503.6372 - mae: 7503.6372
# Epoch 6/300
# 435/435 [==============================] - 1s 3ms/step - loss: 7207.6846 - mae: 7207.6846
# Epoch 7/300
# 435/435 [==============================] - 1s 3ms/step - loss: 6869.7114 - mae: 6869.7114
# Epoch 8/300
# ...

# %%
y_hat_may_1990 = model_may.predict(may_1990_test_X_norm)

y_hat_may_1990
# Out:
# 24/24 [==============================] - 0s 2ms/step
# array([[ 5344.731 ],
#        [ 5024.414 ],
#        [ 4777.346 ],
#        [ 4611.178 ],
#        [ 4732.5273],
#        [ 5511.998 ],
#        [ 6472.9443],
#        [ 7132.162 ],
#        [ 7840.575 ],
#        [ 8538.05  ],
#        [ 8931.612 ],
#        [ 9408.255 ],
#        [ 9880.526 ],
#        [10280.644 ],
#        [10586.742 ],
#        [10863.329 ],
#        [11041.526 ],
#        [10987.959 ],
#        [10500.382 ],
#        [10253.312 ],
#        [ 9952.68  ],
#        [ 8935.9795],
#        [ 7672.2134],
#        [ 6442.3374],
#        [ 5700.954 ],
#        [ 5139.0913],
#        [ 4894.2417],
#        [ 4786.0386],
#        [ 4817.761 ],
#        [ 5540.3633],
#        [ 6616.0557],
#        [ 7303.6763],
#        [ 8095.146 ],
#        [ 8806.815 ],
#        [ 9342.484 ],
#        [ 9816.9375],
#        [10234.548 ],
#        [10541.747 ],
#        [10800.849 ],
#        [11078.531 ],
#        [11158.3545],
# ...

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(may_1990_test_y, y_hat_may_1990)
# Out:
# 281.0381266276042

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(may_1990_test_y, y_hat_may_1990)
# Out:
# 0.0403440255044116

# %%
may_forcast = pd.DataFrame()

may_forcast['True_Load'] = may_1990_test_y
may_forcast['Pred_Load'] = y_hat_may_1990

may_forcast
# Out:
#      True_Load     Pred_Load
# 0         5865   5344.730957
# 1         5572   5024.414062
# 2         5346   4777.346191
# 3         5194   4611.178223
# 4         5305   4732.527344
# ..         ...           ...
# 739      10794  10732.646484
# 740      10807  10746.860352
# 741       9929   9787.012695
# 742       8817   8571.347656
# 743       7812   7472.656250
#
# [744 rows x 2 columns]

# %%
plot_ytrue_yhat(may_1990_test_y, y_hat_may_1990)

# %%
may_forcast.to_csv("Predictions/may.csv")

# %% [markdown]
# ### June Forecast

# %%
may_1990 = final_df_1990_ANN2[2880:3624]
june_1990_train_frames = [apr_sep_1987, apr_sep_1988, apr_sep_1989, april_1990, may_1990]
june_1990_train = pd.concat(june_1990_train_frames)

# %%
june_1990_test = final_df_1990_ANN2[3624:4344]
june_1990_test
# Out:
#       daytype  L(l-1,h)  L(k-1,24)  Max L(k-1)  Min L(k-1)  hourtype   Load
# 3624    0.000    6782.0    11129.0     11736.0      6004.0  0.000000   7089
# 3625    0.000    6378.0    11129.0     11736.0      6004.0  0.043478   6627
# 3626    0.000    6116.0    11129.0     11736.0      6004.0  0.086957   6434
# 3627    0.000    6004.0    11129.0     11736.0      6004.0  0.130435   6238
# 3628    0.000    6062.0    11129.0     11736.0      6004.0  0.173913   6283
# ...       ...       ...        ...         ...         ...       ...    ...
# 4339    0.125   10870.0    11503.0     12417.0      6615.0  0.826087  10669
# 4340    0.125   10830.0    11503.0     12417.0      6615.0  0.869565  10558
# 4341    0.125   10160.0    11503.0     12417.0      6615.0  0.913043   9911
# 4342    0.125    9247.0    11503.0     12417.0      6615.0  0.956522   9126
# 4343    0.125    8364.0    11503.0     12417.0      6615.0  1.000000   8251
#
# [720 rows x 7 columns]

# %%
daytype_train_june = june_1990_train['daytype']
daytype_test_june = june_1990_test['daytype']

hourtype_train = june_1990_train['hourtype']
hourtype_test = june_1990_test['hourtype']

june_1990_train.drop(columns = ['daytype','hourtype'], inplace = True)
june_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

june_1990_train_X = june_1990_train.iloc[:, :5]
june_1990_train_y = june_1990_train['Load']

june_1990_test_X = june_1990_test.iloc[:, :5]
june_1990_test_y = june_1990_test['Load']

june_1990_train_y = june_1990_train_y.values
june_1990_test_y = june_1990_test_y.values
# Out:
# C:\Users\ketul\AppData\Local\Temp\ipykernel_26140\3559310563.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   june_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

june_1990_train_X_norm = scaler.fit_transform(june_1990_train_X)
june_1990_test_X_norm = scaler.fit_transform(june_1990_test_X)

daytype_train_june = daytype_train_june.values
daytype_train_june =  daytype_train_june.reshape(-1,1)

daytype_test_june = daytype_test_june.values
daytype_test_june =  daytype_test_june.reshape(-1,1)

hourtype_train = hourtype_train.values
hourtype_train = hourtype_train.reshape(-1,1)

hourtype_test = hourtype_test.values
hourtype_test = hourtype_test.reshape(-1,1)

june_1990_train_X_norm = np.hstack((june_1990_train_X_norm, daytype_train_june,hourtype_train))
june_1990_test_X_norm = np.hstack((june_1990_test_X_norm, daytype_test_june, hourtype_test))

# %%
import tensorflow as tf

# %%
model_june = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model_june.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.002),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model_june.fit(june_1990_train_X_norm, june_1990_train_y, epochs=300)
# Out:
# Epoch 1/300
# C:\Users\ketul\anaconda3\envs\TensorflowGPU\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 458/458 [==============================] - 1s 2ms/step - loss: 8176.2163 - mae: 8176.2163
# Epoch 2/300
# 458/458 [==============================] - 1s 3ms/step - loss: 8095.7388 - mae: 8095.7388
# Epoch 3/300
# 458/458 [==============================] - 1s 3ms/step - loss: 7944.4692 - mae: 7944.4692
# Epoch 4/300
# 458/458 [==============================] - 1s 2ms/step - loss: 7732.1060 - mae: 7732.1060
# Epoch 5/300
# 458/458 [==============================] - 1s 3ms/step - loss: 7465.9531 - mae: 7465.9531
# Epoch 6/300
# 458/458 [==============================] - 2s 4ms/step - loss: 7151.3960 - mae: 7151.3960
# Epoch 7/300
# 458/458 [==============================] - 1s 3ms/step - loss: 6793.0786 - mae: 6793.0786
# Epoch 8/300
# ...

# %%
y_hat_june_1990 = model_june.predict(june_1990_test_X_norm)

y_hat_june_1990
# Out:
# 23/23 [==============================] - 0s 1ms/step
# array([[ 6064.4375],
#        [ 5613.9243],
#        [ 5425.7236],
#        [ 5234.5947],
#        [ 5278.4736],
#        [ 5885.9766],
#        [ 6747.0137],
#        [ 7570.023 ],
#        [ 8446.663 ],
#        [ 9180.9375],
#        [ 9653.871 ],
#        [ 9950.308 ],
#        [10239.918 ],
#        [10421.291 ],
#        [10570.488 ],
#        [10753.814 ],
#        [10782.091 ],
#        [10533.428 ],
#        [10034.159 ],
#        [ 9610.947 ],
#        [ 9584.617 ],
#        [ 8819.14  ],
#        [ 7982.4824],
#        [ 7078.536 ],
#        [ 6387.1694],
#        [ 5915.204 ],
#        [ 5632.4126],
#        [ 5477.3657],
#        [ 5388.624 ],
#        [ 5538.7812],
#        [ 5784.4976],
#        [ 6690.394 ],
#        [ 7906.389 ],
#        [ 8854.22  ],
#        [ 9425.646 ],
#        [ 9923.941 ],
#        [10072.156 ],
#        [10271.083 ],
#        [10418.325 ],
#        [10536.313 ],
#        [10576.292 ],
# ...

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(june_1990_test_y, y_hat_june_1990)
# Out:
# 1071.5744337293836

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(june_1990_test_y, y_hat_june_1990)
# Out:
# 0.12072592643613954

# %%
june_forcast = pd.DataFrame()

june_forcast['True_Load'] = june_1990_test_y
june_forcast['Pred_Load'] = y_hat_june_1990

june_forcast
# Out:
#      True_Load    Pred_Load
# 0         7089  6064.437500
# 1         6627  5613.924316
# 2         6434  5425.723633
# 3         6238  5234.594727
# 4         6283  5278.473633
# ..         ...          ...
# 715      10669  9555.320312
# 716      10558  9447.078125
# 717       9911  8816.167969
# 718       9126  8050.691406
# 719       8251  7197.450684
#
# [720 rows x 2 columns]

# %%
plot_ytrue_yhat(june_1990_test_y, y_hat_june_1990)

# %%
june_forcast.to_csv("Predictions/june.csv")

# %% [markdown]
# ### July Forecast

# %%
june_1990 = final_df_1990_ANN2[3624:4344]
july_1990_train_frames = [apr_sep_1987, apr_sep_1988, apr_sep_1989, april_1990, may_1990, june_1990]
july_1990_train = pd.concat(july_1990_train_frames)

# %%
july_1990_test = final_df_1990_ANN2[4344:5088]
july_1990_test
# Out:
#       daytype  L(l-1,h)  L(k-1,24)  Max L(k-1)  Min L(k-1)  hourtype   Load
# 4344     0.25    7693.0    11293.0     11860.0      6595.0  0.000000   7527
# 4345     0.25    7210.0    11293.0     11860.0      6595.0  0.043478   7074
# 4346     0.25    6878.0    11293.0     11860.0      6595.0  0.086957   6715
# 4347     0.25    6665.0    11293.0     11860.0      6595.0  0.130435   6496
# 4348     0.25    6595.0    11293.0     11860.0      6595.0  0.173913   6381
# ...       ...       ...        ...         ...         ...       ...    ...
# 5083     0.50   12012.0    12123.0     13367.0      6963.0  0.826087  12099
# 5084     0.50   11833.0    12123.0     13367.0      6963.0  0.869565  11986
# 5085     0.50   10784.0    12123.0     13367.0      6963.0  0.913043  11031
# 5086     0.50    9559.0    12123.0     13367.0      6963.0  0.956522   9848
# 5087     0.50    8381.0    12123.0     13367.0      6963.0  1.000000   8654
#
# [744 rows x 7 columns]

# %%
daytype_train_july = july_1990_train['daytype']
daytype_test_july = july_1990_test['daytype']

hourtype_train = july_1990_train['hourtype']
hourtype_test = july_1990_test['hourtype']

july_1990_train.drop(columns = ['daytype','hourtype'], inplace = True)
july_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

july_1990_train_X = july_1990_train.iloc[:, :5]
july_1990_train_y = july_1990_train['Load']

july_1990_test_X = july_1990_test.iloc[:, :5]
july_1990_test_y = july_1990_test['Load']

july_1990_train_y = july_1990_train_y.values
july_1990_test_y = july_1990_test_y.values
# Out:
# C:\Users\ketul\AppData\Local\Temp\ipykernel_26140\2285511844.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   july_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

july_1990_train_X_norm = scaler.fit_transform(july_1990_train_X)
july_1990_test_X_norm = scaler.fit_transform(july_1990_test_X)

daytype_train_july = daytype_train_july.values
daytype_train_july =  daytype_train_july.reshape(-1,1)

daytype_test_july = daytype_test_july.values
daytype_test_july =  daytype_test_july.reshape(-1,1)

hourtype_train = hourtype_train.values
hourtype_train = hourtype_train.reshape(-1,1)

hourtype_test = hourtype_test.values
hourtype_test = hourtype_test.reshape(-1,1)

july_1990_train_X_norm = np.hstack((july_1990_train_X_norm, daytype_train_july,hourtype_train))
july_1990_test_X_norm = np.hstack((july_1990_test_X_norm, daytype_test_july, hourtype_test))

# %%
model_july = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation = tf.keras.activations.relu), 
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model_july.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.002),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model_july.fit(july_1990_train_X_norm, july_1990_train_y, epochs=300)
# Out:
# Epoch 1/300
# C:\Users\ketul\anaconda3\envs\TensorflowGPU\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 480/480 [==============================] - 1s 2ms/step - loss: 8228.0957 - mae: 8228.0957
# Epoch 2/300
# 480/480 [==============================] - 1s 2ms/step - loss: 8155.8267 - mae: 8155.8267
# Epoch 3/300
# 480/480 [==============================] - 1s 2ms/step - loss: 8016.0156 - mae: 8016.0156
# Epoch 4/300
# 480/480 [==============================] - 1s 2ms/step - loss: 7818.2095 - mae: 7818.2095
# Epoch 5/300
# 480/480 [==============================] - 1s 2ms/step - loss: 7570.4888 - mae: 7570.4888
# Epoch 6/300
# 480/480 [==============================] - 1s 2ms/step - loss: 7278.5635 - mae: 7278.5635
# Epoch 7/300
# 480/480 [==============================] - 1s 2ms/step - loss: 6945.7114 - mae: 6945.7114
# Epoch 8/300
# ...

# %%
y_hat_july_1990 = model_july.predict(july_1990_test_X_norm)

y_hat_july_1990
# Out:
# 24/24 [==============================] - 0s 1ms/step
# array([[ 6362.673 ],
#        [ 5923.2466],
#        [ 5575.004 ],
#        [ 5362.5645],
#        [ 5251.0083],
#        [ 5286.8984],
#        [ 5315.997 ],
#        [ 6043.5186],
#        [ 7134.795 ],
#        [ 8161.0796],
#        [ 8774.134 ],
#        [ 9402.702 ],
#        [ 9876.065 ],
#        [10133.115 ],
#        [10174.823 ],
#        [10031.257 ],
#        [ 9932.3125],
#        [ 9592.801 ],
#        [ 8995.266 ],
#        [ 8526.744 ],
#        [ 8382.207 ],
#        [ 7748.7764],
#        [ 6957.2324],
#        [ 6055.106 ],
#        [ 5511.817 ],
#        [ 5201.401 ],
#        [ 4952.097 ],
#        [ 4913.287 ],
#        [ 4984.089 ],
#        [ 5490.424 ],
#        [ 6167.4775],
#        [ 6930.883 ],
#        [ 7871.8086],
#        [ 8818.552 ],
#        [ 9383.1045],
#        [ 9847.748 ],
#        [10034.967 ],
#        [ 9858.432 ],
#        [ 9093.102 ],
#        [ 8701.215 ],
#        [ 8579.958 ],
# ...

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(july_1990_test_y, y_hat_july_1990)
# Out:
# 1217.9528742964549

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(july_1990_test_y, y_hat_july_1990)
# Out:
# 0.1342076689970488

# %%
july_forcast = pd.DataFrame()

july_forcast['True_Load'] = july_1990_test_y
july_forcast['Pred_Load'] = y_hat_july_1990

july_forcast
# Out:
#      True_Load     Pred_Load
# 0         7527   6362.672852
# 1         7074   5923.246582
# 2         6715   5575.003906
# 3         6496   5362.564453
# 4         6381   5251.008301
# ..         ...           ...
# 739      12099  10797.839844
# 740      11986  10688.220703
# 741      11031   9761.838867
# 742       9848   8614.293945
# 743       8654   7456.079590
#
# [744 rows x 2 columns]

# %%
plot_ytrue_yhat(july_1990_test_y, y_hat_july_1990)

# %%
july_forcast.to_csv("Predictions/july.csv")

# %% [markdown]
# ### August Forecast

# %%
july_1990 = final_df_1990_ANN2[4344:5088]
aug_1990_train_frames = [apr_sep_1987, apr_sep_1988, apr_sep_1989, april_1990, may_1990, june_1990, july_1990]
aug_1990_train = pd.concat(aug_1990_train_frames)

# %%
aug_1990_test = final_df_1990_ANN2[5088:5832]
aug_1990_test
# Out:
#       daytype  L(l-1,h)  L(k-1,24)  Max L(k-1)  Min L(k-1)  hourtype   Load
# 5088    0.625    7774.0    12197.0     13297.0      6879.0  0.000000   8006
# 5089    0.625    7332.0    12197.0     13297.0      6879.0  0.043478   7516
# 5090    0.625    7025.0    12197.0     13297.0      6879.0  0.086957   7191
# 5091    0.625    6879.0    12197.0     13297.0      6879.0  0.130435   7019
# 5092    0.625    6904.0    12197.0     13297.0      6879.0  0.173913   7000
# ...       ...       ...        ...         ...         ...       ...    ...
# 5827    0.000   11889.0    11949.0     12940.0      6605.0  0.826087  11052
# 5828    0.000   11391.0    11949.0     12940.0      6605.0  0.869565  10727
# 5829    0.000   10251.0    11949.0     12940.0      6605.0  0.913043   9908
# 5830    0.000    9182.0    11949.0     12940.0      6605.0  0.956522   9082
# 5831    0.000    8091.0    11949.0     12940.0      6605.0  1.000000   8242
#
# [744 rows x 7 columns]

# %%
daytype_train_aug = aug_1990_train['daytype']
daytype_test_aug = aug_1990_test['daytype']

hourtype_train = aug_1990_train['hourtype']
hourtype_test = aug_1990_test['hourtype']

aug_1990_train.drop(columns = ['daytype','hourtype'], inplace = True)
aug_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

aug_1990_train_X = aug_1990_train.iloc[:, :5]
aug_1990_train_y = aug_1990_train['Load']

aug_1990_test_X = aug_1990_test.iloc[:, :5]
aug_1990_test_y = aug_1990_test['Load']

aug_1990_train_y = aug_1990_train_y.values
aug_1990_test_y = aug_1990_test_y.values
# Out:
# C:\Users\ketul\AppData\Local\Temp\ipykernel_26140\1294732675.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aug_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

aug_1990_train_X_norm = scaler.fit_transform(aug_1990_train_X)
aug_1990_test_X_norm = scaler.fit_transform(aug_1990_test_X)

daytype_train_aug = daytype_train_aug.values
daytype_train_aug =  daytype_train_aug.reshape(-1,1)

daytype_test_aug = daytype_test_aug.values
daytype_test_aug =  daytype_test_aug.reshape(-1,1)

hourtype_train = hourtype_train.values
hourtype_train = hourtype_train.reshape(-1,1)

hourtype_test = hourtype_test.values
hourtype_test = hourtype_test.reshape(-1,1)

aug_1990_train_X_norm = np.hstack((aug_1990_train_X_norm, daytype_train_aug,hourtype_train))
aug_1990_test_X_norm = np.hstack((aug_1990_test_X_norm, daytype_test_aug, hourtype_test))

# %%
model_aug = tf.keras.Sequential([
  tf.keras.layers.Dense(5, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model_aug.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.002),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model_aug.fit(aug_1990_train_X_norm, aug_1990_train_y, epochs=200)
# Out:
# Epoch 1/200
# C:\Users\ketul\anaconda3\envs\TensorflowGPU\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 504/504 [==============================] - 2s 3ms/step - loss: 8292.3115 - mae: 8292.3115
# Epoch 2/200
# 504/504 [==============================] - 1s 3ms/step - loss: 8252.2588 - mae: 8252.2588
# Epoch 3/200
# 504/504 [==============================] - 1s 2ms/step - loss: 8173.7095 - mae: 8173.7095
# Epoch 4/200
# 504/504 [==============================] - 1s 3ms/step - loss: 8064.0815 - mae: 8064.0815
# Epoch 5/200
# 504/504 [==============================] - 3s 6ms/step - loss: 7927.7563 - mae: 7927.7563
# Epoch 6/200
# 504/504 [==============================] - 1s 3ms/step - loss: 7767.2329 - mae: 7767.2329
# Epoch 7/200
# 504/504 [==============================] - 2s 4ms/step - loss: 7584.3164 - mae: 7584.3164
# Epoch 8/200
# ...

# %%
y_hat_aug_1990 = model_aug.predict(aug_1990_test_X_norm)

y_hat_aug_1990
# Out:
# 24/24 [==============================] - 0s 882us/step
# array([[ 6717.226 ],
#        [ 6243.095 ],
#        [ 5928.619 ],
#        [ 5762.1885],
#        [ 5743.8022],
#        [ 6192.773 ],
#        [ 6756.89  ],
#        [ 7646.1226],
#        [ 8638.891 ],
#        [ 9528.125 ],
#        [10207.387 ],
#        [10796.659 ],
#        [11226.275 ],
#        [11659.762 ],
#        [11972.299 ],
#        [12229.68  ],
#        [12072.926 ],
#        [11548.484 ],
#        [11064.676 ],
#        [10640.859 ],
#        [10425.081 ],
#        [ 9497.14  ],
#        [ 8481.144 ],
#        [ 7428.378 ],
#        [ 6648.611 ],
#        [ 6271.2383],
#        [ 6000.304 ],
#        [ 5867.7393],
#        [ 5870.639 ],
#        [ 6328.318 ],
#        [ 6922.429 ],
#        [ 7749.7363],
#        [ 8851.843 ],
#        [ 9825.257 ],
#        [10432.916 ],
#        [10902.208 ],
#        [11248.613 ],
#        [11557.281 ],
#        [11716.9375],
#        [11774.027 ],
#        [11740.157 ],
# ...

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(aug_1990_test_y, y_hat_aug_1990)
# Out:
# 1341.9911840295279

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(aug_1990_test_y, y_hat_aug_1990)
# Out:
# 0.14528136603415448

# %%
aug_forcast = pd.DataFrame()

aug_forcast['True_Load'] = aug_1990_test_y
aug_forcast['Pred_Load'] = y_hat_aug_1990

aug_forcast
# Out:
#      True_Load    Pred_Load
# 0         8006  6717.226074
# 1         7516  6243.095215
# 2         7191  5928.619141
# 3         7019  5762.188477
# 4         7000  5743.802246
# ..         ...          ...
# 739      11052  9664.422852
# 740      10727  9349.943359
# 741       9908  8557.461914
# 742       9082  7758.209473
# 743       8242  6945.409668
#
# [744 rows x 2 columns]

# %%
plot_ytrue_yhat(aug_1990_test_y, y_hat_aug_1990)

# %%
aug_forcast.to_csv("Predictions/aug.csv")

# %% [markdown]
# ### September Forecast

# %%
aug_1990 = final_df_1990_ANN2[5088:5832]
sep_1990_train_frames = [apr_sep_1987, apr_sep_1988, apr_sep_1989, april_1990, may_1990, june_1990, july_1990, aug_1990]
sep_1990_train = pd.concat(sep_1990_train_frames)

# %%
sep_1990_test = final_df_1990_ANN2[5832:6552]
sep_1990_test
# Out:
#       daytype  L(l-1,h)  L(k-1,24)  Max L(k-1)  Min L(k-1)  hourtype  Load
# 5832    0.125    7398.0    11855.0     12324.0      6512.0  0.000000  7596
# 5833    0.125    6994.0    11855.0     12324.0      6512.0  0.043478  7155
# 5834    0.125    6715.0    11855.0     12324.0      6512.0  0.086957  6850
# 5835    0.125    6512.0    11855.0     12324.0      6512.0  0.130435  6614
# 5836    0.125    6562.0    11855.0     12324.0      6512.0  0.173913  6527
# ...       ...       ...        ...         ...         ...       ...   ...
# 6547    0.250    9657.0     9656.0      9986.0      5905.0  0.826087  9613
# 6548    0.250    9141.0     9656.0      9986.0      5905.0  0.869565  9164
# 6549    0.250    8492.0     9656.0      9986.0      5905.0  0.913043  8447
# 6550    0.250    7841.0     9656.0      9986.0      5905.0  0.956522  7598
# 6551    0.250    7045.0     9656.0      9986.0      5905.0  1.000000  6700
#
# [720 rows x 7 columns]

# %%
daytype_train_sep = sep_1990_train['daytype']
daytype_test_sep = sep_1990_test['daytype']

hourtype_train = sep_1990_train['hourtype']
hourtype_test = sep_1990_test['hourtype']

sep_1990_train.drop(columns = ['daytype','hourtype'], inplace = True)
sep_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

sep_1990_train_X = sep_1990_train.iloc[:, :5]
sep_1990_train_y = sep_1990_train['Load']

sep_1990_test_X = sep_1990_test.iloc[:, :5]
sep_1990_test_y = sep_1990_test['Load']

sep_1990_train_y = sep_1990_train_y.values
sep_1990_test_y = sep_1990_test_y.values
# Out:
# C:\Users\ketul\AppData\Local\Temp\ipykernel_26140\1394627695.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sep_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

sep_1990_train_X_norm = scaler.fit_transform(sep_1990_train_X)
sep_1990_test_X_norm = scaler.fit_transform(sep_1990_test_X)

daytype_train_sep = daytype_train_sep.values
daytype_train_sep =  daytype_train_sep.reshape(-1,1)

daytype_test_sep = daytype_test_sep.values
daytype_test_sep =  daytype_test_sep.reshape(-1,1)

hourtype_train = hourtype_train.values
hourtype_train = hourtype_train.reshape(-1,1)

hourtype_test = hourtype_test.values
hourtype_test = hourtype_test.reshape(-1,1)

sep_1990_train_X_norm = np.hstack((sep_1990_train_X_norm, daytype_train_sep,hourtype_train))
sep_1990_test_X_norm = np.hstack((sep_1990_test_X_norm, daytype_test_sep, hourtype_test))

# %%
model_sep = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model_sep.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.002),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model_sep.fit(sep_1990_train_X_norm, sep_1990_train_y, epochs=300)
# Out:
# C:\Users\ketul\anaconda3\envs\TensorflowGPU\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/300
# 527/527 [==============================] - 2s 3ms/step - loss: 8338.1494 - mae: 8338.1494
# Epoch 2/300
# 527/527 [==============================] - 1s 3ms/step - loss: 8235.8359 - mae: 8235.8359
# Epoch 3/300
# 527/527 [==============================] - 1s 3ms/step - loss: 8044.6934 - mae: 8044.6934
# Epoch 4/300
# 527/527 [==============================] - 1s 3ms/step - loss: 7778.2388 - mae: 7778.2388
# Epoch 5/300
# 527/527 [==============================] - 1s 3ms/step - loss: 7446.1528 - mae: 7446.1528
# Epoch 6/300
# 527/527 [==============================] - 1s 3ms/step - loss: 7056.9370 - mae: 7056.9370
# Epoch 7/300
# 527/527 [==============================] - 1s 3ms/step - loss: 6633.2065 - mae: 6633.2065
# Epoch 8/300
# ...

# %%
y_hat_sep_1990 = model_sep.predict(sep_1990_test_X_norm)

y_hat_sep_1990
# Out:
# 23/23 [==============================] - 0s 1ms/step
# array([[ 6371.826 ],
#        [ 5926.1523],
#        [ 5622.7485],
#        [ 5489.8115],
#        [ 5420.2417],
#        [ 5382.4863],
#        [ 5567.465 ],
#        [ 6258.733 ],
#        [ 7347.1685],
#        [ 8248.637 ],
#        [ 8697.368 ],
#        [ 9178.424 ],
#        [ 9588.733 ],
#        [ 9923.2295],
#        [10128.36  ],
#        [10387.054 ],
#        [10460.813 ],
#        [10325.388 ],
#        [ 9870.6045],
#        [ 9876.66  ],
#        [ 9521.925 ],
#        [ 8762.933 ],
#        [ 7991.8125],
#        [ 7146.9204],
#        [ 6466.607 ],
#        [ 5958.2583],
#        [ 5577.2495],
#        [ 5368.0425],
#        [ 5209.3726],
#        [ 5278.092 ],
#        [ 5350.8594],
#        [ 5904.689 ],
#        [ 7095.2017],
#        [ 8126.0327],
#        [ 8797.073 ],
#        [ 9328.657 ],
#        [ 9672.2705],
#        [ 9847.114 ],
#        [10002.75  ],
#        [10143.2295],
#        [10141.208 ],
# ...

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(sep_1990_test_y, y_hat_sep_1990)
# Out:
# 1196.9841871473525

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(sep_1990_test_y, y_hat_sep_1990)
# Out:
# 0.1322683943706941

# %%
sep_forcast = pd.DataFrame()

sep_forcast['True_Load'] = sep_1990_test_y
sep_forcast['Pred_Load'] = y_hat_sep_1990

sep_forcast
# Out:
#      True_Load    Pred_Load
# 0         7596  6371.826172
# 1         7155  5926.152344
# 2         6850  5622.748535
# 3         6614  5489.811523
# 4         6527  5420.241699
# ..         ...          ...
# 715       9613  8409.573242
# 716       9164  7955.791016
# 717       8447  7231.166992
# 718       7598  6373.148438
# 719       6700  5465.603027
#
# [720 rows x 2 columns]

# %%
plot_ytrue_yhat(sep_1990_test_y, y_hat_sep_1990)

# %%
sep_forcast.to_csv("Predictions/sep.csv")

# %% [markdown]
# ### March Forecast

# %%
feb_1987 = final_df_ANN2[744:1416]
mar_1987 = final_df_ANN2[1416:2160]
oct_15_nov_31_1987 = final_df_ANN2[6924:8016]
feb_1988 = final_df_ANN2[9504:10176]
mar_1988 = final_df_ANN2[10176:10920]
oct_15_nov_31_1987 = final_df_ANN2[15684:16776]
feb_1989 = final_df_ANN2[18264:18936]
mar_1989 = final_df_ANN2[18936:19680]
oct_15_nov_31_1989 = final_df_ANN2[24444:25536]


mar_1990_train_frames = [feb_1987, mar_1987,oct_15_nov_31_1987, feb_1988, mar_1988, oct_15_nov_31_1987,feb_1989, mar_1989,  oct_15_nov_31_1989]
mar_1990_train = pd.concat(mar_1990_train_frames)

# %%
mar_1990_test = final_df_1990_ANN2[1416:2160]
mar_1990_test
# Out:
#       daytype  L(l-1,h)  L(k-1,24)  Max L(k-1)  Min L(k-1)  hourtype  Load
# 1416    0.750    4662.0     7623.0      8573.0      4446.0  0.000000  4673
# 1417    0.750    4509.0     7623.0      8573.0      4446.0  0.043478  4486
# 1418    0.750    4446.0     7623.0      8573.0      4446.0  0.086957  4416
# 1419    0.750    4463.0     7623.0      8573.0      4446.0  0.130435  4439
# 1420    0.750    4697.0     7623.0      8573.0      4446.0  0.173913  4685
# ...       ...       ...        ...         ...         ...       ...   ...
# 2155    0.125    9248.0     9373.0      9505.0      5173.0  0.826087  8191
# 2156    0.125    8568.0     9373.0      9505.0      5173.0  0.869565  7630
# 2157    0.125    7920.0     9373.0      9505.0      5173.0  0.913043  7055
# 2158    0.125    7213.0     9373.0      9505.0      5173.0  0.956522  6445
# 2159    0.125    6410.0     9373.0      9505.0      5173.0  1.000000  5738
#
# [744 rows x 7 columns]

# %%
daytype_train_mar = mar_1990_train['daytype']
daytype_test_mar = mar_1990_test['daytype']

hourtype_train = mar_1990_train['hourtype']
hourtype_test = mar_1990_test['hourtype']

mar_1990_train.drop(columns = ['daytype','hourtype'], inplace = True)
mar_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

mar_1990_train_X = mar_1990_train.iloc[:, :5]
mar_1990_train_y = mar_1990_train['Load']

mar_1990_test_X = mar_1990_test.iloc[:, :5]
mar_1990_test_y = mar_1990_test['Load']

mar_1990_train_y = mar_1990_train_y.values
mar_1990_test_y = mar_1990_test_y.values
# Out:
# C:\Users\ketul\AppData\Local\Temp\ipykernel_26140\2601901608.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mar_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

mar_1990_train_X_norm = scaler.fit_transform(mar_1990_train_X)
mar_1990_test_X_norm = scaler.fit_transform(mar_1990_test_X)

daytype_train_mar = daytype_train_mar.values
daytype_train_mar =  daytype_train_mar.reshape(-1,1)

daytype_test_mar = daytype_test_mar.values
daytype_test_mar =  daytype_test_mar.reshape(-1,1)

hourtype_train = hourtype_train.values
hourtype_train = hourtype_train.reshape(-1,1)

hourtype_test = hourtype_test.values
hourtype_test = hourtype_test.reshape(-1,1)

mar_1990_train_X_norm = np.hstack((mar_1990_train_X_norm, daytype_train_mar,hourtype_train))
mar_1990_test_X_norm = np.hstack((mar_1990_test_X_norm, daytype_test_mar, hourtype_test))

# %%
model_mar = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation = tf.keras.activations.relu),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model_mar.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.002),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model_mar.fit(mar_1990_train_X_norm, mar_1990_train_y, epochs=300)
# Out:
# C:\Users\ketul\anaconda3\envs\TensorflowGPU\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/300
# 236/236 [==============================] - 1s 4ms/step - loss: 6769.6392 - mae: 6769.6392
# Epoch 2/300
# 236/236 [==============================] - 1s 3ms/step - loss: 6750.0967 - mae: 6750.0967
# Epoch 3/300
# 236/236 [==============================] - 1s 3ms/step - loss: 6711.9653 - mae: 6711.9653
# Epoch 4/300
# 236/236 [==============================] - 1s 3ms/step - loss: 6656.5737 - mae: 6656.5737
# Epoch 5/300
# 236/236 [==============================] - 1s 3ms/step - loss: 6584.0527 - mae: 6584.0527
# Epoch 6/300
# 236/236 [==============================] - 1s 3ms/step - loss: 6499.4727 - mae: 6499.4727
# Epoch 7/300
# 236/236 [==============================] - 1s 3ms/step - loss: 6395.8608 - mae: 6395.8608
# Epoch 8/300
# ...

# %%
y_hat_mar_1990 = model_mar.predict(mar_1990_test_X_norm)

y_hat_mar_1990
# Out:
# 24/24 [==============================] - 0s 1ms/step
# array([[4103.3994],
#        [3925.7043],
#        [3859.292 ],
#        [3881.3113],
#        [4115.305 ],
#        [5021.1694],
#        [6185.509 ],
#        [6568.7363],
#        [6704.828 ],
#        [6960.9736],
#        [6955.4316],
#        [6951.745 ],
#        [6902.4165],
#        [6854.043 ],
#        [6856.9175],
#        [6899.7793],
#        [7003.32  ],
#        [7165.2437],
#        [7782.2876],
#        [7348.053 ],
#        [6790.212 ],
#        [6194.6035],
#        [5393.346 ],
#        [4567.602 ],
#        [4086.957 ],
#        [3894.105 ],
#        [3813.4126],
#        [3826.8347],
#        [4064.6084],
#        [4949.5874],
#        [6115.0234],
#        [6635.4854],
#        [6979.3667],
#        [7248.534 ],
#        [7335.4434],
#        [7326.0625],
#        [7361.623 ],
#        [7348.5615],
#        [7371.5737],
#        [7383.981 ],
#        [7386.674 ],
#        [7479.76  ],
# ...

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(mar_1990_test_y, y_hat_mar_1990)
# Out:
# 677.7946294969128

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(mar_1990_test_y, y_hat_mar_1990)
# Out:
# 0.0993409069875871

# %%
mar_forcast = pd.DataFrame()

mar_forcast['True_Load'] = mar_1990_test_y
mar_forcast['Pred_Load'] = y_hat_mar_1990

mar_forcast
# Out:
#      True_Load    Pred_Load
# 0         4673  4103.399414
# 1         4486  3925.704346
# 2         4416  3859.291992
# 3         4439  3881.311279
# 4         4685  4115.305176
# ..         ...          ...
# 739       8191  7462.013184
# 740       7630  6929.269043
# 741       7055  6383.089355
# 742       6445  5803.709473
# 743       5738  5132.129883
#
# [744 rows x 2 columns]

# %%
plot_ytrue_yhat(mar_1990_test_y, y_hat_mar_1990)

# %%
mar_forcast.to_csv("Predictions/mar.csv")

# %% [markdown]
# ### October Forecast

# %%
mar_may_1987 = final_df_ANN1[1416:3624]
sep_oct_1987 = final_df_ANN1[5832:7296]
mar_may_1988 = final_df_ANN1[10176:12384]
sep_oct_1988 = final_df_ANN1[14592:16056]
mar_may_1989 = final_df_ANN1[18936:21144]
sep_oct_1988 = final_df_ANN1[23352:24816]

oct_1990_train_frames = [mar_may_1987, sep_oct_1987, mar_may_1988, sep_oct_1988, mar_may_1989, sep_oct_1988]
oct_1990_train = pd.concat(oct_1990_train_frames)

# %%
oct_1990_train = oct_1990_train.dropna(axis = 0)

# %%
oct_1990_train
# Out:
#        daytype    AvgL(k-1)  sqr[maxL(k-1)-AveL(k-1)]  \
# 1416      0.75  5866.416667               2504570.007
# 1417      0.75  5866.416667               2504570.007
# 1418      0.75  5866.416667               2504570.007
# 1419      0.75  5866.416667               2504570.007
# 1420      0.75  5866.416667               2504570.007
# ...        ...          ...                       ...
# 24811     0.00  6963.375000               3582029.391
# 24812     0.00  6963.375000               3582029.391
# 24813     0.00  6963.375000               3582029.391
# 24814     0.00  6963.375000               3582029.391
# 24815     0.00  6963.375000               3582029.391
#
#        sqr[aveL(k-1)-minL(k-1)]  L(k-1,8)  L(l-1,h)  hourtype  Load
# 1416                3416644.174    5637.0    4438.0  0.000000  4586
# 1417                3416644.174    5637.0    4176.0  0.043478  4253
# 1418                3416644.174    5637.0    4035.0  0.086957  4142
# ...

# %%
oct_1990_test = final_df_1990_ANN1[6552:7296]
oct_1990_test
# Out:
#       daytype    AvgL(k-1)  sqr[maxL(k-1)-AveL(k-1)]  \
# 6552    0.375  7876.291667               3016155.835
# 6553    0.375  7876.291667               3016155.835
# 6554    0.375  7876.291667               3016155.835
# 6555    0.375  7876.291667               3016155.835
# 6556    0.375  7876.291667               3016155.835
# ...       ...          ...                       ...
# 7291    0.625  7194.666667               3703058.778
# 7292    0.625  7194.666667               3703058.778
# 7293    0.625  7194.666667               3703058.778
# 7294    0.625  7194.666667               3703058.778
# 7295    0.625  7194.666667               3703058.778
#
#       sqr[aveL(k-1)-minL(k-1)]  L(k-1,8)  L(l-1,h)  hourtype  Load
# 6552               5158765.835    6477.0    6490.0  0.000000  6210
# 6553               5158765.835    6477.0    6093.0  0.043478  5927
# 6554               5158765.835    6477.0    5853.0  0.086957  5767
# ...

# %%
daytype_train_oct = oct_1990_train['daytype']
daytype_test_oct = oct_1990_test['daytype']

hourtype_train = oct_1990_train['hourtype']
hourtype_test = oct_1990_test['hourtype']

oct_1990_train.drop(columns = ['daytype','hourtype'], inplace = True)
oct_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

oct_1990_train_X = oct_1990_train.iloc[:, :5]
oct_1990_train_y = oct_1990_train['Load']

oct_1990_test_X = oct_1990_test.iloc[:, :5]
oct_1990_test_y = oct_1990_test['Load']

oct_1990_train_y = oct_1990_train_y.values
oct_1990_test_y = oct_1990_test_y.values
# Out:
# C:\Users\ketul\AppData\Local\Temp\ipykernel_26140\1514478470.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oct_1990_test.drop(columns = ['daytype','hourtype'], inplace = True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

oct_1990_train_X_norm = scaler.fit_transform(oct_1990_train_X)
oct_1990_test_X_norm = scaler.fit_transform(oct_1990_test_X)

daytype_train_oct = daytype_train_oct.values
daytype_train_oct =  daytype_train_oct.reshape(-1,1)

daytype_test_oct = daytype_test_oct.values
daytype_test_oct =  daytype_test_oct.reshape(-1,1)

hourtype_train = hourtype_train.values
hourtype_train = hourtype_train.reshape(-1,1)

hourtype_test = hourtype_test.values
hourtype_test = hourtype_test.reshape(-1,1)

oct_1990_train_X_norm = np.hstack((oct_1990_train_X_norm, daytype_train_oct, hourtype_train))
oct_1990_test_X_norm = np.hstack((oct_1990_test_X_norm, daytype_test_oct, hourtype_test))

# %%
model_oct = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model_oct.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.002),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model_oct.fit(oct_1990_train_X_norm, oct_1990_train_y, epochs=300)
# Out:
# C:\Users\ketul\anaconda3\envs\TensorflowGPU\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/300
# 345/345 [==============================] - 1s 3ms/step - loss: 7431.2388 - mae: 7431.2388
# Epoch 2/300
# 345/345 [==============================] - 1s 3ms/step - loss: 7380.7485 - mae: 7380.7485
# Epoch 3/300
# 345/345 [==============================] - 1s 3ms/step - loss: 7276.3472 - mae: 7276.3472
# Epoch 4/300
# 345/345 [==============================] - 1s 3ms/step - loss: 7123.9805 - mae: 7123.9805
# Epoch 5/300
# 345/345 [==============================] - 1s 3ms/step - loss: 6930.3711 - mae: 6930.3711
# Epoch 6/300
# 345/345 [==============================] - 1s 3ms/step - loss: 6699.7393 - mae: 6699.7393
# Epoch 7/300
# 345/345 [==============================] - 1s 3ms/step - loss: 6435.3848 - mae: 6435.3848
# Epoch 8/300
# ...

# %%
y_hat_oct_1990 = model_oct.predict(oct_1990_test_X_norm)

y_hat_oct_1990
# Out:
# 24/24 [==============================] - 0s 1ms/step
# array([[ 5286.7705],
#        [ 4955.3735],
#        [ 4757.661 ],
#        [ 4600.8213],
#        [ 4559.784 ],
#        [ 4661.7983],
#        [ 4874.507 ],
#        [ 5322.2285],
#        [ 6130.984 ],
#        [ 6937.1855],
#        [ 7340.629 ],
#        [ 7761.954 ],
#        [ 7953.3755],
#        [ 7902.12  ],
#        [ 7850.0137],
#        [ 7875.3936],
#        [ 7887.1494],
#        [ 7814.6064],
#        [ 7718.2227],
#        [ 8072.2793],
#        [ 7696.6045],
#        [ 7092.729 ],
#        [ 6376.456 ],
#        [ 5618.46  ],
#        [ 4654.1675],
#        [ 4419.841 ],
#        [ 4290.2485],
#        [ 4240.697 ],
#        [ 4370.8105],
#        [ 5010.9697],
#        [ 5938.0825],
#        [ 6260.635 ],
#        [ 6732.198 ],
#        [ 7391.0903],
#        [ 7859.247 ],
#        [ 8179.2446],
#        [ 8532.45  ],
#        [ 8782.625 ],
#        [ 8914.441 ],
#        [ 9007.94  ],
#        [ 9111.657 ],
# ...

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(oct_1990_test_y, y_hat_oct_1990)
# Out:
# 1762.8763086462534

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(oct_1990_test_y, y_hat_oct_1990)
# Out:
# 0.20103528670456042

# %%
oct_forcast = pd.DataFrame()

oct_forcast['True_Load'] = oct_1990_test_y
oct_forcast['Pred_Load'] = y_hat_oct_1990

oct_forcast
# Out:
#      True_Load    Pred_Load
# 0         6210  5286.770508
# 1         5927  4955.373535
# 2         5767  4757.661133
# 3         5701  4600.821289
# 4         5846  4559.784180
# ..         ...          ...
# 739       8309  6661.306641
# 740       7803  6116.184570
# 741       7150  5512.308594
# 742       6278  4844.570801
# 743       5582  4188.754395
#
# [744 rows x 2 columns]

# %%
plot_ytrue_yhat(oct_1990_test_y, y_hat_oct_1990)

# %%
oct_forcast.to_csv("Predictions/oct.csv")
